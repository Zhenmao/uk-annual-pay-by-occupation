# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("PROV - Occupation SOC10 (4) Table 14.7a   Annual pay - Gross 2017.xls",
                   sheet_name=[4],
                   header=4,
                   skip_footer=5,
                   na_values="x")
df
# Out:
#                                   Key points to note:              Unnamed: 1  \
# 0   1. Estimates vary in quality, mainly reflectin...                     NaN
# 1   2. For every table showing estimates of earnin...                     NaN
# 2                                                 NaN                     NaN
# 3   3. Figures for numbers of jobs are not reliabl...                     NaN
# 4                                                 NaN                     NaN
# 5                Estimates available in this document                     NaN
# 6   Estimates for hours and earnings are provided ...                     NaN
# 7                                                 NaN                     NaN
# 8                                                 NaN                     NaN
# 9   Mean - the mean is a measure of the average wh...                     NaN
# 10                                                NaN                     NaN
# ...
